# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing

# %%
df_train = pd.read_excel("Data_Train.xlsx")
df_test = pd.read_excel("Test_set.xlsx")

# %%
df_train
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df_test
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %% [markdown]
# # EDA

# %%
df_train['Arrival_Time'] = df_train['Arrival_Time'].str.split(' ').str[0]

# %%
df_train
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20        01:10   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50        13:15   7h 25m     2 stops
# ...

# %%
df_test['Arrival_Time'] = df_test['Arrival_Time'].str.split(' ').str[0]

# %%
df_test
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30        04:25  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20        10:20       4h      1 stop
# ...

# %%
big_df=df_train.append(df_test, sort=False)

# %%
big_df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20        01:10   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50        13:15   7h 25m     2 stops
# ...

# %%
big_df.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# dtype: int64

# %%
big_df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# dtype: object

# %%
big_df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
big_df['Date']= big_df['Date_of_Journey'].str.split('/').str[0]
big_df['Month']= big_df['Date_of_Journey'].str.split('/').str[1]
big_df['Year']= big_df['Date_of_Journey'].str.split('/').str[2]

# %%
big_df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20        01:10   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50        13:15   7h 25m     2 stops
# ...

# %%
big_df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                object
# Month               object
# Year                object
# dtype: object

# %%
big_df['Date']=big_df['Date'].astype(int)
big_df['Month']=big_df['Month'].astype(int)
big_df['Year']=big_df['Year'].astype(int)

# %%
big_df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int64
# Month                int64
# Year                 int64
# dtype: object

# %%
big_df = big_df.drop(['Date_of_Journey'],axis=1)

# %%
big_df
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
big_df['Arrival_Hour']= big_df['Arrival_Time'].str.split(':').str[0]
big_df['Arrival_Minutes']= big_df['Arrival_Time'].str.split(':').str[1]

# %%
big_df
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
big_df = big_df.drop(['Arrival_Time'],axis=1)

# %%
big_df
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
big_df['Dep_Hour']= big_df['Dep_Time'].str.split(':').str[0]
big_df['Dep_Minutes']= big_df['Dep_Time'].str.split(':').str[1]

# %%
big_df = big_df.drop(['Dep_Time'],axis=1)

# %%
big_df
# Out:
#                 Airline    Source Destination                  Route Duration  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR  23h 55m
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR   2h 35m
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK   6h 35m
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK  15h 15m
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK  14h 20m
#
# ...

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int64
# Month                int64
# Year                 int64
# Arrival_Hour        object
# Arrival_Minutes     object
# Dep_Hour            object
# Dep_Minutes         object
# dtype: object

# %%
big_df['Arrival_Hour']=big_df['Arrival_Hour'].astype(int)
big_df['Arrival_Minutes']=big_df['Arrival_Minutes'].astype(int)
big_df['Dep_Hour']=big_df['Dep_Hour'].astype(int)
big_df['Dep_Minutes']=big_df['Dep_Minutes'].astype(int)

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int64
# Month                int64
# Year                 int64
# Arrival_Hour         int64
# Arrival_Minutes      int64
# Dep_Hour             int64
# Dep_Minutes          int64
# dtype: object

# %%
big_df['Total_Stops'] = big_df['Total_Stops'].replace('non-stop','0 stop')

# %%
big_df
# Out:
#                 Airline    Source Destination                  Route Duration  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR  23h 55m
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR   2h 35m
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK   6h 35m
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK  15h 15m
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK  14h 20m
#
# ...

# %%
big_df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# Arrival_Hour          0
# Arrival_Minutes       0
# Dep_Hour              0
# Dep_Minutes           0
# dtype: int64

# %%
big_df[big_df['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route Duration Total_Stops Additional_Info  \
# 9039  Air India  Delhi      Cochin   NaN  23h 40m         NaN         No info
#
#        Price  Date  Month  Year  Arrival_Hour  Arrival_Minutes  Dep_Hour  \
# 9039  7480.0     6      5  2019             9               25         9
#
#       Dep_Minutes
# 9039           45

# %%
big_df['Total_Stops'] = big_df['Total_Stops'].fillna('1 stop')

# %%
big_df['Stops']= big_df['Total_Stops'].str.split(' ').str[0]

# %%
big_df
# Out:
#                 Airline    Source Destination                  Route Duration  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR  23h 55m
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR   2h 35m
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK   6h 35m
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK  15h 15m
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK  14h 20m
#
# ...

# %%
big_df['Route'] = big_df['Route'].fillna('None')

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int64
# Month                int64
# Year                 int64
# Arrival_Hour         int64
# Arrival_Minutes      int64
# Dep_Hour             int64
# Dep_Minutes          int64
# Stops               object
# dtype: object

# %%
big_df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 0
# Duration              0
# Total_Stops           0
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# Arrival_Hour          0
# Arrival_Minutes       0
# Dep_Hour              0
# Dep_Minutes           0
# Stops                 0
# dtype: int64

# %%
big_df['Route_1'] = big_df['Route'].str.split('→').str[0]
big_df['Route_2'] = big_df['Route'].str.split('→').str[1]
big_df['Route_3'] = big_df['Route'].str.split('→').str[2]
big_df['Route_4'] = big_df['Route'].str.split('→').str[3]
big_df['Route_5'] = big_df['Route'].str.split('→').str[4]

# %%
big_df
# Out:
#                 Airline    Source Destination                  Route Duration  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR  23h 55m
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR   2h 35m
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK   6h 35m
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK  15h 15m
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK  14h 20m
#
# ...

# %%
big_df['Route_1'].fillna("None",inplace=True)
big_df['Route_2'].fillna("None",inplace=True)
big_df['Route_3'].fillna("None",inplace=True)
big_df['Route_4'].fillna("None",inplace=True)
big_df['Route_5'].fillna("None",inplace=True)

# %%
big_df
# Out:
#                 Airline    Source Destination                  Route Duration  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR  23h 55m
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR   2h 35m
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK   6h 35m
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK  15h 15m
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK  14h 20m
#
# ...

# %%
big_df = big_df.drop(['Route'],axis=1)

# %%
big_df = big_df.drop(['Total_Stops'],axis=1)

# %%
big_df
# Out:
#                 Airline    Source Destination Duration Additional_Info  \
# 0                IndiGo  Banglore   New Delhi   2h 50m         No info
# 1             Air India   Kolkata    Banglore   7h 25m         No info
# 2           Jet Airways     Delhi      Cochin      19h         No info
# 3                IndiGo   Kolkata    Banglore   5h 25m         No info
# 4                IndiGo  Banglore   New Delhi   4h 45m         No info
# ...                 ...       ...         ...      ...             ...
# 2666          Air India   Kolkata    Banglore  23h 55m         No info
# 2667             IndiGo   Kolkata    Banglore   2h 35m         No info
# 2668        Jet Airways     Delhi      Cochin   6h 35m         No info
# 2669          Air India     Delhi      Cochin  15h 15m         No info
# 2670  Multiple carriers     Delhi      Cochin  14h 20m         No info
#
#         Price  Date  Month  Year  Arrival_Hour  Arrival_Minutes  Dep_Hour  \
# ...

# %%
big_df['Stops']=big_df['Stops'].astype(int)

# %%
big_df['Duration']=  big_df['Duration'].str.replace("h", '*60').str.replace(' ','+').str.replace('m','*1').apply(eval)

# %%
big_df
# Out:
#                 Airline    Source Destination  Duration Additional_Info  \
# 0                IndiGo  Banglore   New Delhi       170         No info
# 1             Air India   Kolkata    Banglore       445         No info
# 2           Jet Airways     Delhi      Cochin      1140         No info
# 3                IndiGo   Kolkata    Banglore       325         No info
# 4                IndiGo  Banglore   New Delhi       285         No info
# ...                 ...       ...         ...       ...             ...
# 2666          Air India   Kolkata    Banglore      1435         No info
# 2667             IndiGo   Kolkata    Banglore       155         No info
# 2668        Jet Airways     Delhi      Cochin       395         No info
# 2669          Air India     Delhi      Cochin       915         No info
# 2670  Multiple carriers     Delhi      Cochin       860         No info
#
#         Price  Date  Month  Year  Arrival_Hour  Arrival_Minutes  Dep_Hour  \
# ...

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
big_df['Airline']=label_encoder.fit_transform(big_df['Airline'])

# %%
big_df['Airline'].unique()
# Out:
# array([ 3,  1,  4,  8,  6,  2, 10,  0, 11,  5,  7,  9])

# %%
big_df
# Out:
#       Airline    Source Destination  Duration Additional_Info    Price  Date  \
# 0           3  Banglore   New Delhi       170         No info   3897.0    24
# 1           1   Kolkata    Banglore       445         No info   7662.0     1
# 2           4     Delhi      Cochin      1140         No info  13882.0     9
# 3           3   Kolkata    Banglore       325         No info   6218.0    12
# 4           3  Banglore   New Delhi       285         No info  13302.0     1
# ...       ...       ...         ...       ...             ...      ...   ...
# 2666        1   Kolkata    Banglore      1435         No info      NaN     6
# 2667        3   Kolkata    Banglore       155         No info      NaN    27
# 2668        4     Delhi      Cochin       395         No info      NaN     6
# 2669        1     Delhi      Cochin       915         No info      NaN     6
# 2670        6     Delhi      Cochin       860         No info      NaN    15
#
# ...

# %%
big_df['Source']=label_encoder.fit_transform(big_df['Source'])
big_df['Destination']=label_encoder.fit_transform(big_df['Destination'])
big_df['Additional_Info']=label_encoder.fit_transform(big_df['Additional_Info'])
big_df['Route_1']=label_encoder.fit_transform(big_df['Route_1'])
big_df['Route_2']=label_encoder.fit_transform(big_df['Route_2'])
big_df['Route_3']=label_encoder.fit_transform(big_df['Route_3'])
big_df['Route_4']=label_encoder.fit_transform(big_df['Route_4'])
big_df['Route_5']=label_encoder.fit_transform(big_df['Route_5'])

# %%
big_df
# Out:
#       Airline  Source  Destination  Duration  Additional_Info    Price  Date  \
# 0           3       0            5       170                8   3897.0    24
# 1           1       3            0       445                8   7662.0     1
# 2           4       2            1      1140                8  13882.0     9
# 3           3       3            0       325                8   6218.0    12
# 4           3       0            5       285                8  13302.0     1
# ...       ...     ...          ...       ...              ...      ...   ...
# 2666        1       3            0      1435                8      NaN     6
# 2667        3       3            0       155                8      NaN    27
# 2668        4       2            1       395                8      NaN     6
# 2669        1       2            1       915                8      NaN     6
# 2670        6       2            1       860                8      NaN    15
#
# ...

# %%
big_df.describe()
# Out:
#             Airline        Source   Destination     Duration  Additional_Info  \
# count  13354.000000  13354.000000  13354.000000  13354.00000     13354.000000
# mean       3.977086      1.954096      1.435450    642.42287         7.407743
# std        2.363997      1.178607      1.473368    506.71504         1.198393
# min        0.000000      0.000000      0.000000      5.00000         0.000000
# 25%        3.000000      2.000000      0.000000    175.00000         8.000000
# 50%        4.000000      2.000000      1.000000    520.00000         8.000000
# 75%        4.000000      3.000000      2.000000    930.00000         8.000000
# max       11.000000      4.000000      5.000000   2860.00000         9.000000
#
#               Price          Date         Month     Year  Arrival_Hour  \
# count  10683.000000  13354.000000  13354.000000  13354.0  13354.000000
# mean    9087.064121     13.389846      4.710574   2019.0     13.396061
# ...

# %%
big_df.dtypes
# Out:
# Airline              int64
# Source               int64
# Destination          int64
# Duration             int64
# Additional_Info      int64
# Price              float64
# Date                 int64
# Month                int64
# Year                 int64
# Arrival_Hour         int64
# Arrival_Minutes      int64
# Dep_Hour             int64
# Dep_Minutes          int64
# Stops                int64
# Route_1              int64
# Route_2              int64
# Route_3              int64
# Route_4              int64
# Route_5              int64
# dtype: object

# %%
big_df['Additional_Info'].unique()
# Out:
# array([8, 5, 7, 1, 6, 0, 4, 3, 9, 2])

# %%
count = big_df['Route_4'].value_counts()
print(count)
# Out:
# 13    11397
# 5      1373
# 3       390
# 6        98
# 9        38
# 4        33
# 7         9
# 12        5
# 10        4
# 8         3
# 11        1
# 2         1
# 1         1
# 0         1
# Name: Route_4, dtype: int64

# %%
big_df['Route_4'].unique()
# Out:
# array([13,  3,  5,  6,  4,  9,  7, 10,  8, 12,  1,  2,  0, 11])

# %%
big_df.skew()
# Out:
# Airline             0.720924
# Source             -0.424151
# Destination         1.247893
# Duration            0.867883
# Additional_Info    -1.784752
# Price               1.812552
# Date                0.135142
# Month              -0.390684
# Year                0.000000
# Arrival_Hour       -0.384591
# Arrival_Minutes     0.111711
# Dep_Hour            0.109087
# Dep_Minutes         0.159397
# Stops               0.317797
# Route_1            -0.618133
# Route_2             1.426787
# Route_3             0.636124
# Route_4            -2.084009
# Route_5           -15.985555
# dtype: float64

# %%
for col in big_df.columns:
    if big_df.skew().loc[col]>0.55:
        big_df[col]=np.log1p(big_df[col])
# Out:
# /Users/vishaln/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:853: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
big_df.skew()
# Out:
# Airline            -0.680746
# Source             -0.424151
# Destination         0.283069
# Duration           -0.179667
# Additional_Info    -1.784752
# Price              -0.254565
# Date                0.135142
# Month              -0.390684
# Year                0.000000
# Arrival_Hour       -0.384591
# Arrival_Minutes     0.111711
# Dep_Hour            0.109087
# Dep_Minutes         0.159397
# Stops               0.317797
# Route_1            -0.618133
# Route_2            -0.835693
# Route_3             0.324430
# Route_4            -2.084009
# Route_5           -15.985555
# dtype: float64

# %%
train_df = big_df[0:10683]
test_df = big_df[10683:]
test_df = test_df.drop(['Price'], axis =1)

# %%
train_df
# Out:
#         Airline  Source  Destination  Duration  Additional_Info     Price  \
# 0      1.386294       0     1.791759  5.141664                8  8.268219
# 1      0.693147       3     0.000000  6.100319                8  8.944159
# 2      1.609438       2     0.693147  7.039660                8  9.538420
# 3      1.386294       3     0.000000  5.786897                8  8.735364
# 4      1.386294       0     1.791759  5.655992                8  9.495745
# ...         ...     ...          ...       ...              ...       ...
# 10678  0.000000       3     0.000000  5.017280                8  8.320692
# 10679  0.693147       3     0.000000  5.049856                8  8.329899
# 10680  1.609438       0     1.098612  5.198497                8  8.885994
# 10681  2.397895       0     1.791759  5.081404                8  9.445333
# 10682  0.693147       2     0.693147  6.216606                8  9.371949
#
#        Date  Month  Year  Arrival_Hour  Arrival_Minutes  Dep_Hour  \
# ...

# %%
test_df
# Out:
#        Airline  Source  Destination  Duration  Additional_Info  Date  Month  \
# 0     1.609438       2     0.693147  6.486161                8     6      6
# 1     1.386294       3     0.000000  5.484797                8    12      5
# 2     1.609438       2     0.693147  7.262629                5    21      5
# 3     1.945910       2     0.693147  6.660575                8    21      5
# 4     0.000000       0     1.098612  5.141664                8    24      6
# ...        ...     ...          ...       ...              ...   ...    ...
# 2666  0.693147       3     0.000000  7.269617                8     6      6
# 2667  1.386294       3     0.000000  5.049856                8    27      3
# 2668  1.609438       2     0.693147  5.981414                8     6      3
# 2669  0.693147       2     0.693147  6.820016                8     6      3
# 2670  1.945910       2     0.693147  6.758095                8    15      6
#
# ...

# %%
x = train_df.drop(['Price'], axis=1)
y = train_df['Price']

# %%
x
# Out:
#         Airline  Source  Destination  Duration  Additional_Info  Date  Month  \
# 0      1.386294       0     1.791759  5.141664                8    24      3
# 1      0.693147       3     0.000000  6.100319                8     1      5
# 2      1.609438       2     0.693147  7.039660                8     9      6
# 3      1.386294       3     0.000000  5.786897                8    12      5
# 4      1.386294       0     1.791759  5.655992                8     1      3
# ...         ...     ...          ...       ...              ...   ...    ...
# 10678  0.000000       3     0.000000  5.017280                8     9      4
# 10679  0.693147       3     0.000000  5.049856                8    27      4
# 10680  1.609438       0     1.098612  5.198497                8    27      4
# 10681  2.397895       0     1.791759  5.081404                8     1      3
# 10682  0.693147       2     0.693147  6.216606                8     9      5
#
# ...

# %%
y
# Out:
# 0        8.268219
# 1        8.944159
# 2        9.538420
# 3        8.735364
# 4        9.495745
#            ...
# 10678    8.320692
# 10679    8.329899
# 10680    8.885994
# 10681    9.445333
# 10682    9.371949
# Name: Price, Length: 10683, dtype: float64

# %% [markdown]
# # Model Selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    lr=linear_model.LinearRegression()
    lr.fit(x_train,y_train)
    y_pred = lr.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state 
print("max r2 score corresponding to",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.6035868925151171
# r2 score corresponding to random state:  43 is:  0.627516818269986
# r2 score corresponding to random state:  44 is:  0.6062712238642178
# r2 score corresponding to random state:  45 is:  0.599648340829843
# r2 score corresponding to random state:  46 is:  0.6232115381736303
# r2 score corresponding to random state:  47 is:  0.6195066439773598
# r2 score corresponding to random state:  48 is:  0.6289775696063941
# r2 score corresponding to random state:  49 is:  0.6180560610317913
# r2 score corresponding to random state:  50 is:  0.6316041667831109
# r2 score corresponding to random state:  51 is:  0.6343330735313812
# r2 score corresponding to random state:  52 is:  0.6185672272601757
# r2 score corresponding to random state:  53 is:  0.6027384695187057
# r2 score corresponding to random state:  54 is:  0.6324294375520325
# r2 score corresponding to random state:  55 is:  0.6258843399758206
# ...

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring="r2").mean()
# Out:
# 0.6208082756642923

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=77,test_size=0.20)
lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)
y_predlr=lr.predict(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr = GridSearchCV(knr, neighbors, cv=5)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 2}

# %%
knr=KNeighborsRegressor(n_neighbors=2)
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    knr.fit(x_train,y_train)
    y_pred = knr.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state 
print("max r2 score corresponding to",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.7319152316108719
# r2 score corresponding to random state:  43 is:  0.7431788793953313
# r2 score corresponding to random state:  44 is:  0.7123965099693771
# r2 score corresponding to random state:  45 is:  0.74541633557762
# r2 score corresponding to random state:  46 is:  0.7276775465663613
# r2 score corresponding to random state:  47 is:  0.7365975266308465
# r2 score corresponding to random state:  48 is:  0.7332080510380162
# r2 score corresponding to random state:  49 is:  0.7192418396636133
# r2 score corresponding to random state:  50 is:  0.7424751603502
# r2 score corresponding to random state:  51 is:  0.7538310529774273
# r2 score corresponding to random state:  52 is:  0.7291965977233295
# r2 score corresponding to random state:  53 is:  0.7187814998795183
# r2 score corresponding to random state:  54 is:  0.743877778201971
# r2 score corresponding to random state:  55 is:  0.7324648979472445
# ...

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2score for kNeighbors Regression: ",cross_val_score(knr,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for kNeighbors Regression: ",cross_val_score(knr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for kNeighbors Regression:  0.7320133695940972
# Standard deviation in r2 score for kNeighbors Regression:  0.013512274120229694

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=100,test_size=0.20)
knr.fit(x_train,y_train)
y_predknr=knr.predict(x_test)

# %%
from sklearn.linear_model import Lasso
parameters={"alpha":[0.001,0.01,0.1,1]}
lsreg=Lasso()
glsr = GridSearchCV(lsreg, parameters, cv=5)
glsr.fit(x,y)
glsr.best_params_
# Out:
# {'alpha': 0.001}

# %%
lsreg=Lasso(alpha=0.001)
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    lsreg.fit(x_train,y_train)
    y_pred = lsreg.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state 
print("max r2 score corresponding to",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.6033232553119084
# r2 score corresponding to random state:  43 is:  0.6272852028632725
# r2 score corresponding to random state:  44 is:  0.6062610010232562
# r2 score corresponding to random state:  45 is:  0.5989359525321192
# r2 score corresponding to random state:  46 is:  0.6234455843078113
# r2 score corresponding to random state:  47 is:  0.61895417379369
# r2 score corresponding to random state:  48 is:  0.6281739166713258
# r2 score corresponding to random state:  49 is:  0.6183175515613956
# r2 score corresponding to random state:  50 is:  0.6321286727158105
# r2 score corresponding to random state:  51 is:  0.6343454880656207
# r2 score corresponding to random state:  52 is:  0.6183769156820953
# r2 score corresponding to random state:  53 is:  0.6026111834325056
# r2 score corresponding to random state:  54 is:  0.6322864629253371
# r2 score corresponding to random state:  55 is:  0.6251525846400263
# ...

# %%
print("Mean r2score for gradient boosting Regression: ",cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Gradient Boosting Regression: ",cross_val_score(lsreg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for gradient boosting Regression:  0.6206555917633718
# Standard deviation in r2 score for Gradient Boosting Regression:  0.015908808734722012

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=77,test_size=0.20)
lsreg.fit(x_train,y_train)
y_predlas=lsreg.predict(x_test)

# %%
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
ggbr = GridSearchCV(gbr, parameters, cv=5)
ggbr.fit(x,y)
ggbr.best_params_
# Out:
# {'learning_rate': 1, 'n_estimators': 1000}

# %%
gbr=GradientBoostingRegressor(learning_rate=1,n_estimators=1000)
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    gbr.fit(x_train,y_train)
    y_pred = gbr.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state 
print("max r2 score corresponding to",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.9374960862305888
# r2 score corresponding to random state:  43 is:  0.9456133139866736
# r2 score corresponding to random state:  44 is:  0.932972101655559
# r2 score corresponding to random state:  45 is:  0.9276865506528531
# r2 score corresponding to random state:  46 is:  0.9338265736839325
# r2 score corresponding to random state:  47 is:  0.9437352620133714
# r2 score corresponding to random state:  48 is:  0.9335270804609015
# r2 score corresponding to random state:  49 is:  0.9385303102606215
# r2 score corresponding to random state:  50 is:  0.942384825490411
# r2 score corresponding to random state:  51 is:  0.9426658889836302
# r2 score corresponding to random state:  52 is:  0.9404286990397804
# r2 score corresponding to random state:  53 is:  0.9271155400939308
# r2 score corresponding to random state:  54 is:  0.9351261147784833
# r2 score corresponding to random state:  55 is:  0.9308423242703381
# ...

# %%
print("Mean r2score for gradient boosting Regression: ",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Gradient Boosting Regression: ",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for gradient boosting Regression:  0.936182219445351
# Standard deviation in r2 score for Gradient Boosting Regression:  0.0039933314739599435

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=77,test_size=0.20)
gbr.fit(x_train,y_train)
y_predgbr=gbr.predict(x_test)

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lr,lsreg,DecisionTreeRegressor()]}
gada = GridSearchCV(ada_reg, parameters, cv=5)
gada.fit(x,y)
gada.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=None, splitter='best'),
#  'learning_rate': 0.1,
#  'n_estimators': 500}

# %%
ada_reg=AdaBoostRegressor(learning_rate=0.1,n_estimators=500)
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    ada_reg.fit(x_train,y_train)
    y_pred = ada_reg.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state 
print("max r2 score corresponding to",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.6645227084401233
# r2 score corresponding to random state:  43 is:  0.6883647950561277
# r2 score corresponding to random state:  44 is:  0.6759474104123309
# r2 score corresponding to random state:  45 is:  0.6735837959866933
# r2 score corresponding to random state:  46 is:  0.6718147986392623
# r2 score corresponding to random state:  47 is:  0.6903679314948866
# r2 score corresponding to random state:  48 is:  0.6948283033153635
# r2 score corresponding to random state:  49 is:  0.6791782003487739
# r2 score corresponding to random state:  50 is:  0.6833677149778521
# r2 score corresponding to random state:  51 is:  0.6767946317119278
# r2 score corresponding to random state:  52 is:  0.6731865156456157
# r2 score corresponding to random state:  53 is:  0.6623640586656292
# r2 score corresponding to random state:  54 is:  0.6962337767712574
# r2 score corresponding to random state:  55 is:  0.6701578645873779
# ...

# %%
print("Mean r2score for Ada boosting Regression: ",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Ada Boosting Regression: ",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for Ada boosting Regression:  0.6812442195264253
# Standard deviation in r2 score for Ada Boosting Regression:  0.016997903762610057

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=58,test_size=0.20)
ada_reg.fit(x_train,y_train)
y_predada=ada_reg.predict(x_test)

# %% [markdown]
# # Model Selection

# %%
I choose GradientBoostingRegressor Model as my preferred model as it performs better on the above dataset.

# %% [markdown]
# # Save the Model

# %%
from sklearn.externals import joblib

# %%
joblib.dump(gbr,'Model_FlightPrediction.csv')
