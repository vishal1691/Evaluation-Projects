# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
df_train = pd.read_excel("Data_Train1.xlsx")
df_test = pd.read_excel("Data_Test.xlsx")

# %%
df_train
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 12685        QUICK BITES          13228
# 12686  CASUAL DINING,BAR           9686
# 12687             LOUNGE          11133
# 12688      CASUAL DINING           6134
# 12689      CASUAL DINING           6430
#
#                                                CUISINES  \
# 0                           Malwani, Goan, North Indian
# 1                        Asian, Modern Indian, Japanese
# 2            North Indian, Chinese, Biryani, Hyderabadi
# 3                                      Tibetan, Chinese
# 4                                              Desserts
# ...                                                 ...
# 12685                       North Indian, Burger, Kebab
# ...

# %%
df_test
# Out:
#               TITLE  RESTAURANT_ID  \
# 0     CASUAL DINING           4085
# 1       QUICK BITES          12680
# 2     CASUAL DINING           1411
# 3              None            204
# 4       QUICK BITES          13453
# ...             ...            ...
# 4226  CASUAL DINING           9057
# 4227           None           1247
# 4228    QUICK BITES           8617
# 4229    QUICK BITES           6485
# 4230    QUICK BITES           2421
#
#                                            CUISINES  \
# 0             North Indian, Chinese, Mughlai, Kebab
# 1      South Indian, Fast Food, Pizza, North Indian
# 2           North Indian, Seafood, Biryani, Chinese
# 3                                           Biryani
# 4                              South Indian, Kerala
# ...                                             ...
# 4226                 North Indian, Mughlai, Chinese
# 4227  Biryani, North Indian, Sandwich, Salad, Wraps
# 4228                      Continental, North Indian
# ...

# %%
df_train.dtypes
# Out:
# TITLE            object
# RESTAURANT_ID     int64
# CUISINES         object
# TIME             object
# CITY             object
# LOCALITY         object
# RATING           object
# VOTES            object
# COST              int64
# dtype: object

# %% [markdown]
# # EDA

# %%
big_df=df_train.append(df_test, sort=False)

# %%
big_df.dtypes
# Out:
# TITLE             object
# RESTAURANT_ID      int64
# CUISINES          object
# TIME              object
# CITY              object
# LOCALITY          object
# RATING            object
# VOTES             object
# COST             float64
# dtype: object

# %%
big_df
# Out:
#                   TITLE  RESTAURANT_ID  \
# 0         CASUAL DINING           9438
# 1     CASUAL DINING,BAR          13198
# 2         CASUAL DINING          10915
# 3           QUICK BITES           6346
# 4        DESSERT PARLOR          15387
# ...                 ...            ...
# 4226      CASUAL DINING           9057
# 4227               None           1247
# 4228        QUICK BITES           8617
# 4229        QUICK BITES           6485
# 4230        QUICK BITES           2421
#
#                                            CUISINES  \
# 0                       Malwani, Goan, North Indian
# 1                    Asian, Modern Indian, Japanese
# 2        North Indian, Chinese, Biryani, Hyderabadi
# 3                                  Tibetan, Chinese
# 4                                          Desserts
# ...                                             ...
# 4226                 North Indian, Mughlai, Chinese
# 4227  Biryani, North Indian, Sandwich, Salad, Wraps
# ...

# %%
big_df['CITY'].fillna(big_df['CITY'].mode()[0], inplace=True)

# %%
big_df.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY                0
# LOCALITY          128
# RATING              4
# VOTES            1606
# COST             4231
# dtype: int64

# %%
big_df['LOCALITY'].fillna(big_df['LOCALITY'].mode()[0], inplace=True)

# %%
big_df['VOTES'].fillna(big_df['VOTES'].mode()[0], inplace=True)
big_df['RATING'].fillna(big_df['RATING'].mode()[0], inplace=True)

# %%
big_df.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY                0
# LOCALITY            0
# RATING              0
# VOTES               0
# COST             4231
# dtype: int64

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
big_df['CITY']=label_encoder.fit_transform(big_df['CITY'])

# %%
big_df['CITY'].unique()
# Out:
# array([400,  75, 277,  42, 146, 160, 216, 403,  17, 316,  19, 256,   8,
#         41, 300,  40, 111, 323,  50, 371, 168, 247,  92, 128,  72, 251,
#        445, 390, 138, 191, 197, 124, 180, 127,  58, 310, 215,  59, 233,
#        141,  53, 387, 182, 219, 333, 274, 373, 391, 348, 134, 377,   4,
#        286, 351, 117, 225, 189, 222, 114, 150, 368, 185,  60,  24,  10,
#        113, 119,   7, 187,  28, 231, 264, 137, 424, 337, 426,  35,  83,
#        266,  80, 173, 246, 126, 364, 434, 218, 228,  43, 360, 161, 163,
#        301, 196, 344, 409, 145,  51, 212, 440, 142, 157, 431, 278,  90,
#         71, 315, 243, 303, 346, 240, 151, 392, 355, 320, 263, 365, 448,
#         57, 335,  68, 291, 283, 428,  29,  87, 165,  11, 395, 167, 152,
#        261, 109, 296,  96, 107, 195,  62,  12, 399, 361,  27, 314, 213,
#        358, 235, 129, 394, 115, 272, 308, 327, 442, 349,  91,  94, 326,
#        164, 285,  93, 255, 239, 350, 319,  97, 209, 422, 401, 311,  38,
# ...

# %%
big_df
# Out:
#                   TITLE  RESTAURANT_ID  \
# 0         CASUAL DINING           9438
# 1     CASUAL DINING,BAR          13198
# 2         CASUAL DINING          10915
# 3           QUICK BITES           6346
# 4        DESSERT PARLOR          15387
# ...                 ...            ...
# 4226      CASUAL DINING           9057
# 4227               None           1247
# 4228        QUICK BITES           8617
# 4229        QUICK BITES           6485
# 4230        QUICK BITES           2421
#
#                                            CUISINES  \
# 0                       Malwani, Goan, North Indian
# 1                    Asian, Modern Indian, Japanese
# 2        North Indian, Chinese, Biryani, Hyderabadi
# 3                                  Tibetan, Chinese
# 4                                          Desserts
# ...                                             ...
# 4226                 North Indian, Mughlai, Chinese
# 4227  Biryani, North Indian, Sandwich, Salad, Wraps
# ...

# %%
big_df['LOCALITY']=label_encoder.fit_transform(big_df['LOCALITY'])

# %%
big_df['LOCALITY'].unique()
# Out:
# array([ 328, 1214, 1272, ..., 1040, 1251, 1148])

# %%
big_df
# Out:
#                   TITLE  RESTAURANT_ID  \
# 0         CASUAL DINING           9438
# 1     CASUAL DINING,BAR          13198
# 2         CASUAL DINING          10915
# 3           QUICK BITES           6346
# 4        DESSERT PARLOR          15387
# ...                 ...            ...
# 4226      CASUAL DINING           9057
# 4227               None           1247
# 4228        QUICK BITES           8617
# 4229        QUICK BITES           6485
# 4230        QUICK BITES           2421
#
#                                            CUISINES  \
# 0                       Malwani, Goan, North Indian
# 1                    Asian, Modern Indian, Japanese
# 2        North Indian, Chinese, Biryani, Hyderabadi
# 3                                  Tibetan, Chinese
# 4                                          Desserts
# ...                                             ...
# 4226                 North Indian, Mughlai, Chinese
# 4227  Biryani, North Indian, Sandwich, Salad, Wraps
# ...

# %%
big_df.dtypes
# Out:
# TITLE             object
# RESTAURANT_ID      int64
# CUISINES          object
# TIME              object
# CITY               int64
# LOCALITY           int64
# RATING            object
# VOTES             object
# COST             float64
# dtype: object

# %%
big_df['RATING'] = big_df['RATING'].replace('-','0.0')

# %%
big_df['RATING'] = big_df['RATING'].replace('NEW','0.0')

# %%
big_df['RATING']=big_df['RATING'].astype(float)

# %%
big_df.dtypes
# Out:
# TITLE             object
# RESTAURANT_ID      int64
# CUISINES          object
# TIME              object
# CITY               int64
# LOCALITY           int64
# RATING           float64
# VOTES             object
# COST             float64
# dtype: object

# %%
big_df
# Out:
#                   TITLE  RESTAURANT_ID  \
# 0         CASUAL DINING           9438
# 1     CASUAL DINING,BAR          13198
# 2         CASUAL DINING          10915
# 3           QUICK BITES           6346
# 4        DESSERT PARLOR          15387
# ...                 ...            ...
# 4226      CASUAL DINING           9057
# 4227               None           1247
# 4228        QUICK BITES           8617
# 4229        QUICK BITES           6485
# 4230        QUICK BITES           2421
#
#                                            CUISINES  \
# 0                       Malwani, Goan, North Indian
# 1                    Asian, Modern Indian, Japanese
# 2        North Indian, Chinese, Biryani, Hyderabadi
# 3                                  Tibetan, Chinese
# 4                                          Desserts
# ...                                             ...
# 4226                 North Indian, Mughlai, Chinese
# 4227  Biryani, North Indian, Sandwich, Salad, Wraps
# ...

# %%
big_df['CUISINES']=label_encoder.fit_transform(big_df['CUISINES'])

# %%
big_df['CUISINES'].unique()
# Out:
# array([3294,  364, 3729, ..., 2355, 3840, 4760])

# %%
big_df
# Out:
#                   TITLE  RESTAURANT_ID  CUISINES  \
# 0         CASUAL DINING           9438      3294
# 1     CASUAL DINING,BAR          13198       364
# 2         CASUAL DINING          10915      3729
# 3           QUICK BITES           6346      5156
# 4        DESSERT PARLOR          15387      2218
# ...                 ...            ...       ...
# 4226      CASUAL DINING           9057      4259
# 4227               None           1247       785
# 4228        QUICK BITES           8617      2089
# 4229        QUICK BITES           6485      4580
# 4230        QUICK BITES           2421      3491
#
#                                                    TIME  CITY  LOCALITY  \
# 0                11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)   400       328
# 1                                  6pm – 11pm (Mon-Sun)    75      1214
# 2                   11am – 3:30pm, 7pm – 11pm (Mon-Sun)    75      1272
# 3                               11:30am – 1am (Mon-Sun)   277       161
# ...

# %%
big_df.dtypes
# Out:
# TITLE             object
# RESTAURANT_ID      int64
# CUISINES           int64
# TIME              object
# CITY               int64
# LOCALITY           int64
# RATING           float64
# VOTES             object
# COST             float64
# dtype: object

# %%
big_df['TITLE']=label_encoder.fit_transform(big_df['TITLE'])

# %%
big_df['TITLE'].unique()
# Out:
# array([ 34,  36, 104,  55,  24,  90, 107,  41,   7,  95,  11,   9,  97,
#         17,  65,  33,  20, 122,  63,   0,   5,  14,  70,  79,  57,  82,
#         73, 111, 116,  21, 100,  89,  92,  45,  76, 113,  46,  66,  62,
#         72,  81,   4,  37,  64,  29, 110, 103,  80,  58,  26, 120,  44,
#         91,  56, 115,  22,  42,  38, 108,  10,  28, 109,  43,  35,  25,
#         87, 105,  13, 119,  88, 102,   2,  51,  68,  53, 106,   6,  98,
#         59, 112,   1,  47,   8, 117,  40,  96,  18,  71,  50,  27,  61,
#         93,  83, 121,  16,  54,  60,  86, 118,  67,  19,  78,  39,  84,
#         99,  32,  12,  52,  94,  30,  77,  85,  15,  74,  75,   3, 101,
#         31,  69,  49, 114,  48,  23])

# %%
big_df
# Out:
#       TITLE  RESTAURANT_ID  CUISINES  \
# 0        34           9438      3294
# 1        36          13198       364
# 2        34          10915      3729
# 3       104           6346      5156
# 4        55          15387      2218
# ...     ...            ...       ...
# 4226     34           9057      4259
# 4227     95           1247       785
# 4228    104           8617      2089
# 4229    104           6485      4580
# 4230    104           2421      3491
#
#                                                    TIME  CITY  LOCALITY  \
# 0                11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)   400       328
# 1                                  6pm – 11pm (Mon-Sun)    75      1214
# 2                   11am – 3:30pm, 7pm – 11pm (Mon-Sun)    75      1272
# 3                               11:30am – 1am (Mon-Sun)   277       161
# 4                                  11am – 1am (Mon-Sun)   277       709
# ...                                                 ...   ...       ...
# ...

# %%
big_df.dtypes
# Out:
# TITLE              int64
# RESTAURANT_ID      int64
# CUISINES           int64
# TIME              object
# CITY               int64
# LOCALITY           int64
# RATING           float64
# VOTES             object
# COST             float64
# dtype: object

# %%
big_df['TIME']=label_encoder.fit_transform(big_df['TIME'])

# %%
big_df['VOTES']=label_encoder.fit_transform(big_df['VOTES'])

# %%
big_df
# Out:
#       TITLE  RESTAURANT_ID  CUISINES  TIME  CITY  LOCALITY  RATING  VOTES  \
# 0        34           9438      3294   898   400       328     3.6   1470
# 1        36          13198       364  2301    75      1214     4.2   1105
# 2        34          10915      3729   806    75      1272     3.8    822
# 3       104           6346      5156   340   277       161     4.1    908
# 4        55          15387      2218   750   277       709     3.8    535
# ...     ...            ...       ...   ...   ...       ...     ...    ...
# 4226     34           9057      4259   290   316      1184     3.9   1060
# 4227     95           1247       785   750    42       461     4.3   1436
# 4228    104           8617      2089  2896   128      1370     3.7   1526
# 4229    104           6485      4580   605   216       642     0.0   1384
# 4230    104           2421      3491  2150    40      1148     3.7   1656
#
#         COST
# 0     1200.0
# 1     1500.0
# 2      800.0
# 3      800.0
# ...

# %%
big_df.dtypes
# Out:
# TITLE              int64
# RESTAURANT_ID      int64
# CUISINES           int64
# TIME               int64
# CITY               int64
# LOCALITY           int64
# RATING           float64
# VOTES              int64
# COST             float64
# dtype: object

# %%
big_df
# Out:
#       TITLE  RESTAURANT_ID  CUISINES  TIME  CITY  LOCALITY  RATING  VOTES  \
# 0        34           9438      3294   898   400       328     3.6   1470
# 1        36          13198       364  2301    75      1214     4.2   1105
# 2        34          10915      3729   806    75      1272     3.8    822
# 3       104           6346      5156   340   277       161     4.1    908
# 4        55          15387      2218   750   277       709     3.8    535
# ...     ...            ...       ...   ...   ...       ...     ...    ...
# 4226     34           9057      4259   290   316      1184     3.9   1060
# 4227     95           1247       785   750    42       461     4.3   1436
# 4228    104           8617      2089  2896   128      1370     3.7   1526
# 4229    104           6485      4580   605   216       642     0.0   1384
# 4230    104           2421      3491  2150    40      1148     3.7   1656
#
#         COST
# 0     1200.0
# 1     1500.0
# 2      800.0
# 3      800.0
# ...

# %%
big_df.dtypes
# Out:
# TITLE              int64
# RESTAURANT_ID      int64
# CUISINES           int64
# TIME               int64
# CITY               int64
# LOCALITY           int64
# RATING           float64
# VOTES              int64
# COST             float64
# dtype: object

# %%
big_df.describe()
# Out:
#               TITLE  RESTAURANT_ID      CUISINES          TIME          CITY  \
# count  16921.000000   16921.000000  16921.000000  16921.000000  16921.000000
# mean      65.004137    7767.211631   2801.322380   1446.928491    174.967732
# std       35.875571    4493.287626   1504.771403    925.974559    106.862761
# min        0.000000       0.000000      0.000000      0.000000      0.000000
# 25%       34.000000    3873.000000   1478.000000    681.000000     75.000000
# 50%       64.000000    7751.000000   3054.000000   1372.000000    160.000000
# 75%      104.000000   11672.000000   4008.000000   2265.000000    277.000000
# max      122.000000   15573.000000   5182.000000   3294.000000    449.000000
#
#            LOCALITY        RATING         VOTES          COST
# count  16921.000000  16921.000000  16921.000000  12690.000000
# mean     751.936647      3.426204   1137.751788    655.252246
# std      459.011780      1.179454    550.765711    627.003540
# ...

# %%
big_df
# Out:
#       TITLE  RESTAURANT_ID  CUISINES  TIME  CITY  LOCALITY  RATING  VOTES  \
# 0        34           9438      3294   898   400       328     3.6   1470
# 1        36          13198       364  2301    75      1214     4.2   1105
# 2        34          10915      3729   806    75      1272     3.8    822
# 3       104           6346      5156   340   277       161     4.1    908
# 4        55          15387      2218   750   277       709     3.8    535
# ...     ...            ...       ...   ...   ...       ...     ...    ...
# 4226     34           9057      4259   290   316      1184     3.9   1060
# 4227     95           1247       785   750    42       461     4.3   1436
# 4228    104           8617      2089  2896   128      1370     3.7   1526
# 4229    104           6485      4580   605   216       642     0.0   1384
# 4230    104           2421      3491  2150    40      1148     3.7   1656
#
#         COST
# 0     1200.0
# 1     1500.0
# 2      800.0
# 3      800.0
# ...

# %%
train_df = big_df[0:12690]
test_df = big_df[12690:]
test_df = test_df.drop(['COST'], axis =1)

# %%
train_df
# Out:
#        TITLE  RESTAURANT_ID  CUISINES  TIME  CITY  LOCALITY  RATING  VOTES  \
# 0         34           9438      3294   898   400       328     3.6   1470
# 1         36          13198       364  2301    75      1214     4.2   1105
# 2         34          10915      3729   806    75      1272     3.8    822
# 3        104           6346      5156   340   277       161     4.1    908
# 4         55          15387      2218   750   277       709     3.8    535
# ...      ...            ...       ...   ...   ...       ...     ...    ...
# 12685    104          13228      3676  1401   160       395     3.8   1548
# 12686     36           9686      2684  1445   277       158     4.3    211
# 12687     79          11133      2617  1391   300      1548     4.0   1632
# 12688     34           6134      4400  2244    75       720     3.5   1159
# 12689     34           6430      3690  1013   160      1539     3.4   1711
#
#          COST
# 0      1200.0
# 1      1500.0
# 2       800.0
# ...

# %%
test_df
# Out:
#       TITLE  RESTAURANT_ID  CUISINES  TIME  CITY  LOCALITY  RATING  VOTES
# 0        34           4085      3878  1417   323      1314     4.3   1573
# 1       104          12680      4879  2548   277       429     4.2   1634
# 2        34           1411      4333   614   277       774     3.8   1227
# 3        95            204       631  2955   128       846     3.8    394
# 4       104          13453      4891   586   216       570     3.6    864
# ...     ...            ...       ...   ...   ...       ...     ...    ...
# 4226     34           9057      4259   290   316      1184     3.9   1060
# 4227     95           1247       785   750    42       461     4.3   1436
# 4228    104           8617      2089  2896   128      1370     3.7   1526
# 4229    104           6485      4580   605   216       642     0.0   1384
# 4230    104           2421      3491  2150    40      1148     3.7   1656
#
# [4231 rows x 8 columns]

# %%
x = train_df.drop(['COST'], axis=1)
y = train_df['COST']

# %%
x
# Out:
#        TITLE  RESTAURANT_ID  CUISINES  TIME  CITY  LOCALITY  RATING  VOTES
# 0         34           9438      3294   898   400       328     3.6   1470
# 1         36          13198       364  2301    75      1214     4.2   1105
# 2         34          10915      3729   806    75      1272     3.8    822
# 3        104           6346      5156   340   277       161     4.1    908
# 4         55          15387      2218   750   277       709     3.8    535
# ...      ...            ...       ...   ...   ...       ...     ...    ...
# 12685    104          13228      3676  1401   160       395     3.8   1548
# 12686     36           9686      2684  1445   277       158     4.3    211
# 12687     79          11133      2617  1391   300      1548     4.0   1632
# 12688     34           6134      4400  2244    75       720     3.5   1159
# 12689     34           6430      3690  1013   160      1539     3.4   1711
#
# [12690 rows x 8 columns]

# %%
y
# Out:
# 0        1200.0
# 1        1500.0
# 2         800.0
# 3         800.0
# 4         300.0
#           ...
# 12685     500.0
# 12686    1800.0
# 12687    1300.0
# 12688     400.0
# 12689     600.0
# Name: COST, Length: 12690, dtype: float64

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    lr=linear_model.LinearRegression()
    lr.fit(x_train,y_train)
    y_pred = lr.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state 
print("max r2 score corresponding to",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.1282666235194665
# r2 score corresponding to random state:  43 is:  0.13509842283980655
# r2 score corresponding to random state:  44 is:  0.11391619749753668
# r2 score corresponding to random state:  45 is:  0.1206493530191356
# r2 score corresponding to random state:  46 is:  0.12091283609404857
# r2 score corresponding to random state:  47 is:  0.11012972593919301
# r2 score corresponding to random state:  48 is:  0.11995890071449777
# r2 score corresponding to random state:  49 is:  0.10004452950415188
# r2 score corresponding to random state:  50 is:  0.13157489338838058
# r2 score corresponding to random state:  51 is:  0.128948847225537
# r2 score corresponding to random state:  52 is:  0.09646697822677763
# r2 score corresponding to random state:  53 is:  0.12128243922257442
# r2 score corresponding to random state:  54 is:  0.11405918687398897
# r2 score corresponding to random state:  55 is:  0.12235208500063433
# ...

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring="r2").mean()
# Out:
# 0.12063308916668933

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr = GridSearchCV(knr, neighbors, cv=5)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 29}

# %%
knr=KNeighborsRegressor(n_neighbors=29)
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    knr.fit(x_train,y_train)
    y_pred = knr.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state 
print("max r2 score corresponding to",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.06946242083786336
# r2 score corresponding to random state:  43 is:  0.07419515942147736
# r2 score corresponding to random state:  44 is:  0.06094311151690035
# r2 score corresponding to random state:  45 is:  0.06973488275159434
# r2 score corresponding to random state:  46 is:  0.0720473311459997
# r2 score corresponding to random state:  47 is:  0.06335845236626492
# r2 score corresponding to random state:  48 is:  0.06817387522357088
# r2 score corresponding to random state:  49 is:  0.0778986093733165
# r2 score corresponding to random state:  50 is:  0.09956459377427429
# r2 score corresponding to random state:  51 is:  0.06280677344135299
# r2 score corresponding to random state:  52 is:  0.07150110076914395
# r2 score corresponding to random state:  53 is:  0.08413066423929394
# r2 score corresponding to random state:  54 is:  0.06492481422269292
# r2 score corresponding to random state:  55 is:  0.05422751484787269
# ...

# %%
from sklearn.linear_model import Lasso
parameters={"alpha":[0.001,0.01,0.1,1]}
lsreg=Lasso()
glsr = GridSearchCV(lsreg, parameters, cv=5)
glsr.fit(x,y)
glsr.best_params_
# Out:
# {'alpha': 1}

# %%
lsreg=Lasso(alpha=1)
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    lsreg.fit(x_train,y_train)
    y_pred = lsreg.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state 
print("max r2 score corresponding to",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.1282742939042465
# r2 score corresponding to random state:  43 is:  0.1350140935185743
# r2 score corresponding to random state:  44 is:  0.1139378202156135
# r2 score corresponding to random state:  45 is:  0.12067824672171734
# r2 score corresponding to random state:  46 is:  0.12089601929141969
# r2 score corresponding to random state:  47 is:  0.11014105802282481
# r2 score corresponding to random state:  48 is:  0.11998082106695596
# r2 score corresponding to random state:  49 is:  0.10013051007746754
# r2 score corresponding to random state:  50 is:  0.13153054377875228
# r2 score corresponding to random state:  51 is:  0.12899446076949805
# r2 score corresponding to random state:  52 is:  0.0964687323463781
# r2 score corresponding to random state:  53 is:  0.12131692271000316
# r2 score corresponding to random state:  54 is:  0.11414241259596325
# r2 score corresponding to random state:  55 is:  0.12241251235204098
# ...

# %%
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
ggbr = GridSearchCV(gbr, parameters, cv=5)
ggbr.fit(x,y)
ggbr.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 1000}

# %%
gbr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=1000)
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    gbr.fit(x_train,y_train)
    y_pred = gbr.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state 
print("max r2 score corresponding to",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.7366306880078811
# r2 score corresponding to random state:  43 is:  0.7732031490520008
# r2 score corresponding to random state:  44 is:  0.7436354469548097
# r2 score corresponding to random state:  45 is:  0.7092902743974505
# r2 score corresponding to random state:  46 is:  0.761154584966677
# r2 score corresponding to random state:  47 is:  0.7551965021486398
# r2 score corresponding to random state:  48 is:  0.7442573693085937
# r2 score corresponding to random state:  49 is:  0.6529306169373366
# r2 score corresponding to random state:  50 is:  0.7469427535170133
# r2 score corresponding to random state:  51 is:  0.7274175212432988
# r2 score corresponding to random state:  52 is:  0.6569661254465812
# r2 score corresponding to random state:  53 is:  0.7461463009621478
# r2 score corresponding to random state:  54 is:  0.7451629635768529
# r2 score corresponding to random state:  55 is:  0.7402726370000134
# ...

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lr,lsreg,DecisionTreeRegressor()]}
gada = GridSearchCV(ada_reg, parameters, cv=5)
gada.fit(x,y)
gada.best_params_

# %%
ada_reg=AdaBoostRegressor(learning_rate=1,n_estimators=1000)
print("Mean r2score for Ada boosting Regression: ",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Ada Boosting Regression: ",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").std())

# %%
r_state=maxr2_score(ada_reg,x,y)

# %% [markdown]
# # Model Selection

# %%
I choose GradientBoostingRegressor Model as my preferred model as it performs better on the above dataset.

# %% [markdown]
# # Save the Model

# %%
from sklearn.externals import joblib

# %%
joblib.dump(gbr,'Model_RestaurantCostPrediction.csv')
