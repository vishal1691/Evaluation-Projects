# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing

# %%
df_train = pd.read_excel("Final_Train.xlsx")
df_test = pd.read_excel("Final_Test.xlsx")

# %%
df_train
# Out:
#                        Qualification           Experience Rating  \
# 0              BHMS, MD - Homeopathy  24 years experience   100%
# 1       BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2     MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3                BSc - Zoology, BAMS  12 years experience    NaN
# 4                               BAMS  20 years experience   100%
# ...                              ...                  ...    ...
# 5956                  MBBS, MS - ENT  19 years experience    98%
# 5957                            MBBS  33 years experience    NaN
# 5958                            MBBS  41 years experience    97%
# 5959     MBBS, MD - General Medicine  15 years experience    90%
# 5960         BDS, MDS - Orthodontics  17 years experience   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# ...

# %%
df_test
# Out:
#                                         Qualification           Experience  \
# 0                                                MBBS  35 years experience
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                          MBBS, DDVL  40 years experience
# 3                                                BAMS   0 years experience
# 4     BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
# ...                                               ...                  ...
# 1982                         BAMS, Doctor of Medicine  10 years experience
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS   4 years experience
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology   9 years experience
# 1985                                              BDS  12 years experience
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy   8 years experience
#
#      Rating                        Place           Profile  \
# ...

# %% [markdown]
# # EDA

# %%
df_train.isnull().sum()
# Out:
# Qualification            0
# Experience               0
# Rating                3302
# Place                   25
# Profile                  0
# Miscellaneous_Info    2620
# Fees                     0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Qualification            0
# Experience               0
# Rating                1090
# Place                    6
# Profile                  0
# Miscellaneous_Info     834
# dtype: int64

# %%
df_train.dtypes
# Out:
# Qualification         object
# Experience            object
# Rating                object
# Place                 object
# Profile               object
# Miscellaneous_Info    object
# Fees                   int64
# dtype: object

# %%
df_train['Rating'].fillna(df_train['Rating'].mode()[0], inplace=True)

# %%
df_train['Miscellaneous_Info'].fillna(df_train['Miscellaneous_Info'].mode()[0], inplace=True)

# %%
df_train.isnull().sum()
# Out:
# Qualification          0
# Experience             0
# Rating                 0
# Place                 25
# Profile                0
# Miscellaneous_Info     0
# Fees                   0
# dtype: int64

# %%
df_train['Place'].fillna(df_train['Place'].mode()[0], inplace=True)

# %%
df_train.isnull().sum()
# Out:
# Qualification         0
# Experience            0
# Rating                0
# Place                 0
# Profile               0
# Miscellaneous_Info    0
# Fees                  0
# dtype: int64

# %%
df_train
# Out:
#                        Qualification           Experience Rating  \
# 0              BHMS, MD - Homeopathy  24 years experience   100%
# 1       BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2     MBBS, MS - Otorhinolaryngology   9 years experience   100%
# 3                BSc - Zoology, BAMS  12 years experience   100%
# 4                               BAMS  20 years experience   100%
# ...                              ...                  ...    ...
# 5956                  MBBS, MS - ENT  19 years experience    98%
# 5957                            MBBS  33 years experience   100%
# 5958                            MBBS  41 years experience    97%
# 5959     MBBS, MD - General Medicine  15 years experience    90%
# 5960         BDS, MDS - Orthodontics  17 years experience   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# ...

# %%
df_test['Rating'].fillna(df_test['Rating'].mode()[0], inplace=True)

# %%
df_test['Miscellaneous_Info'].fillna(df_test['Miscellaneous_Info'].mode()[0], inplace=True)

# %%
df_test['Place'].fillna(df_test['Place'].mode()[0], inplace=True)

# %%
df_test.isnull().sum()
# Out:
# Qualification         0
# Experience            0
# Rating                0
# Place                 0
# Profile               0
# Miscellaneous_Info    0
# dtype: int64

# %%
df_test
# Out:
#                                         Qualification           Experience  \
# 0                                                MBBS  35 years experience
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                          MBBS, DDVL  40 years experience
# 3                                                BAMS   0 years experience
# 4     BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
# ...                                               ...                  ...
# 1982                         BAMS, Doctor of Medicine  10 years experience
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS   4 years experience
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology   9 years experience
# 1985                                              BDS  12 years experience
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy   8 years experience
#
#      Rating                        Place           Profile  \
# ...

# %%
big_df=df_train.append(df_test, sort=False)

# %%
big_df
# Out:
#                                        Qualification           Experience  \
# 0                              BHMS, MD - Homeopathy  24 years experience
# 1                       BAMS, MD - Ayurveda Medicine  12 years experience
# 2                     MBBS, MS - Otorhinolaryngology   9 years experience
# 3                                BSc - Zoology, BAMS  12 years experience
# 4                                               BAMS  20 years experience
# ...                                              ...                  ...
# 1982                        BAMS, Doctor of Medicine  10 years experience
# 1983  MD - Dermatology , Venereology & Leprosy, MBBS   4 years experience
# 1984        MBBS, MD / MS - Obstetrics & Gynaecology   9 years experience
# 1985                                             BDS  12 years experience
# 1986  MBBS, MD - Dermatology , Venereology & Leprosy   8 years experience
#
#      Rating                         Place           Profile  \
# ...

# %%
big_df.isnull().sum()
# Out:
# Qualification            0
# Experience               0
# Rating                   0
# Place                    0
# Profile                  0
# Miscellaneous_Info       0
# Fees                  1987
# dtype: int64

# %%
big_df.dtypes
# Out:
# Qualification          object
# Experience             object
# Rating                 object
# Place                  object
# Profile                object
# Miscellaneous_Info     object
# Fees                  float64
# dtype: object

# %%
big_df
# Out:
#                                        Qualification           Experience  \
# 0                              BHMS, MD - Homeopathy  24 years experience
# 1                       BAMS, MD - Ayurveda Medicine  12 years experience
# 2                     MBBS, MS - Otorhinolaryngology   9 years experience
# 3                                BSc - Zoology, BAMS  12 years experience
# 4                                               BAMS  20 years experience
# ...                                              ...                  ...
# 1982                        BAMS, Doctor of Medicine  10 years experience
# 1983  MD - Dermatology , Venereology & Leprosy, MBBS   4 years experience
# 1984        MBBS, MD / MS - Obstetrics & Gynaecology   9 years experience
# 1985                                             BDS  12 years experience
# 1986  MBBS, MD - Dermatology , Venereology & Leprosy   8 years experience
#
#      Rating                         Place           Profile  \
# ...

# %%
big_df.dtypes
# Out:
# Qualification          object
# Experience             object
# Rating                 object
# Place                  object
# Profile                object
# Miscellaneous_Info     object
# Fees                  float64
# dtype: object

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
big_df['Qualification']=label_encoder.fit_transform(big_df['Qualification'])

# %%
big_df
# Out:
#       Qualification           Experience Rating                         Place  \
# 0               491  24 years experience   100%           Kakkanad, Ernakulam
# 1                92  12 years experience    98%         Whitefield, Bangalore
# 2              1442   9 years experience   100%    Mathikere - BEL, Bangalore
# 3               572  12 years experience   100%  Bannerghatta Road, Bangalore
# 4                16  20 years experience   100%         Keelkattalai, Chennai
# ...             ...                  ...    ...                           ...
# 1982             64  10 years experience   100%       Basavanagudi, Bangalore
# 1983           1561   4 years experience   100%              Choolai, Chennai
# 1984           1344   9 years experience   100%                Porur, Chennai
# 1985            168  12 years experience    98%            Arekere, Bangalore
# 1986           1108   8 years experience   100%         Pallikaranai, Chennai
#
# ...

# %%
big_df['Place']=label_encoder.fit_transform(big_df['Place'])

# %%
big_df
# Out:
#       Qualification           Experience Rating  Place           Profile  \
# 0               491  24 years experience   100%    327         Homeopath
# 1                92  12 years experience    98%    936          Ayurveda
# 2              1442   9 years experience   100%    499    ENT Specialist
# 3               572  12 years experience   100%     74          Ayurveda
# 4                16  20 years experience   100%    369          Ayurveda
# ...             ...                  ...    ...    ...               ...
# 1982             64  10 years experience   100%     76          Ayurveda
# 1983           1561   4 years experience   100%    135    Dermatologists
# 1984           1344   9 years experience   100%    664  General Medicine
# 1985            168  12 years experience    98%     34           Dentist
# 1986           1108   8 years experience   100%    613    Dermatologists
#
#                                      Miscellaneous_Info   Fees
# ...

# %%
big_df['Profile']=label_encoder.fit_transform(big_df['Profile'])

# %%
big_df
# Out:
#       Qualification           Experience Rating  Place  Profile  \
# 0               491  24 years experience   100%    327        5
# 1                92  12 years experience    98%    936        0
# 2              1442   9 years experience   100%    499        3
# 3               572  12 years experience   100%     74        0
# 4                16  20 years experience   100%    369        0
# ...             ...                  ...    ...    ...      ...
# 1982             64  10 years experience   100%     76        0
# 1983           1561   4 years experience   100%    135        2
# 1984           1344   9 years experience   100%    664        4
# 1985            168  12 years experience    98%     34        1
# 1986           1108   8 years experience   100%    613        2
#
#                                      Miscellaneous_Info   Fees
# 0                  100% 16 Feedback Kakkanad, Ernakulam  100.0
# 1                 98% 76 Feedback Whitefield, Bangalore  350.0
# ...

# %%
big_df
# Out:
#       Qualification           Experience Rating  Place  Profile  \
# 0               491  24 years experience   100%    327        5
# 1                92  12 years experience    98%    936        0
# 2              1442   9 years experience   100%    499        3
# 3               572  12 years experience   100%     74        0
# 4                16  20 years experience   100%    369        0
# ...             ...                  ...    ...    ...      ...
# 1982             64  10 years experience   100%     76        0
# 1983           1561   4 years experience   100%    135        2
# 1984           1344   9 years experience   100%    664        4
# 1985            168  12 years experience    98%     34        1
# 1986           1108   8 years experience   100%    613        2
#
#                                      Miscellaneous_Info   Fees
# 0                  100% 16 Feedback Kakkanad, Ernakulam  100.0
# 1                 98% 76 Feedback Whitefield, Bangalore  350.0
# ...

# %%
big_df.dtypes
# Out:
# Qualification           int64
# Experience             object
# Rating                 object
# Place                   int64
# Profile                 int64
# Miscellaneous_Info     object
# Fees                  float64
# dtype: object

# %%
big_df['Miscellaneous_Info']=label_encoder.fit_transform(big_df['Miscellaneous_Info'])

# %%
big_df.dtypes
# Out:
# Qualification           int64
# Experience             object
# Rating                 object
# Place                   int64
# Profile                 int64
# Miscellaneous_Info      int64
# Fees                  float64
# dtype: object

# %%
big_df
# Out:
#       Qualification           Experience Rating  Place  Profile  \
# 0               491  24 years experience   100%    327        5
# 1                92  12 years experience    98%    936        0
# 2              1442   9 years experience   100%    499        3
# 3               572  12 years experience   100%     74        0
# 4                16  20 years experience   100%    369        0
# ...             ...                  ...    ...    ...      ...
# 1982             64  10 years experience   100%     76        0
# 1983           1561   4 years experience   100%    135        2
# 1984           1344   9 years experience   100%    664        4
# 1985            168  12 years experience    98%     34        1
# 1986           1108   8 years experience   100%    613        2
#
#       Miscellaneous_Info   Fees
# 0                    188  100.0
# 1                   1951  350.0
# 2                   2174  300.0
# 3                   2299  250.0
# ...

# %%
big_df.dtypes
# Out:
# Qualification           int64
# Experience             object
# Rating                 object
# Place                   int64
# Profile                 int64
# Miscellaneous_Info      int64
# Fees                  float64
# dtype: object

# %%
big_df['Rating']=label_encoder.fit_transform(big_df['Rating'])

# %%
big_df.dtypes
# Out:
# Qualification           int64
# Experience             object
# Rating                  int64
# Place                   int64
# Profile                 int64
# Miscellaneous_Info      int64
# Fees                  float64
# dtype: object

# %%
big_df['Experience']=label_encoder.fit_transform(big_df['Experience'])

# %%
big_df
# Out:
#       Qualification  Experience  Rating  Place  Profile  Miscellaneous_Info  \
# 0               491          16       0    327        5                 188
# 1                92           3      50    936        0                1951
# 2              1442          63       0    499        3                2174
# 3               572           3       0     74        0                2299
# 4                16          12       0    369        0                 341
# ...             ...         ...     ...    ...      ...                 ...
# 1982             64           1       0     76        0                2174
# 1983           1561          33       0    135        2                2174
# 1984           1344          63       0    664        4                2174
# 1985            168           3      50     34        1                3573
# 1986           1108          62       0    613        2                  25
#
#        Fees
# 0     100.0
# 1     350.0
# 2     300.0
# ...

# %%
big_df.dtypes
# Out:
# Qualification           int64
# Experience              int64
# Rating                  int64
# Place                   int64
# Profile                 int64
# Miscellaneous_Info      int64
# Fees                  float64
# dtype: object

# %%
big_df['Experience']=big_df['Experience'].astype(int)

# %%
big_df.dtypes
# Out:
# Qualification           int64
# Experience              int64
# Rating                  int64
# Place                   int64
# Profile                 int64
# Miscellaneous_Info      int64
# Fees                  float64
# dtype: object

# %%
big_df
# Out:
#       Qualification  Experience  Rating  Place  Profile  Miscellaneous_Info  \
# 0               491          16       0    327        5                 188
# 1                92           3      50    936        0                1951
# 2              1442          63       0    499        3                2174
# 3               572           3       0     74        0                2299
# 4                16          12       0    369        0                 341
# ...             ...         ...     ...    ...      ...                 ...
# 1982             64           1       0     76        0                2174
# 1983           1561          33       0    135        2                2174
# 1984           1344          63       0    664        4                2174
# 1985            168           3      50     34        1                3573
# 1986           1108          62       0    613        2                  25
#
#        Fees
# 0     100.0
# 1     350.0
# 2     300.0
# ...

# %%
big_df.skew()
# Out:
# Qualification         0.247541
# Experience            0.826304
# Rating                0.805754
# Place                 0.111599
# Profile               0.088789
# Miscellaneous_Info   -0.306820
# Fees                  0.751870
# dtype: float64

# %%
train_df = big_df[0:5961]
test_df = big_df[5961:]

# %%
train_df
# Out:
#       Qualification  Experience  Rating  Place  Profile  Miscellaneous_Info  \
# 0               491          16       0    327        5                 188
# 1                92           3      50    936        0                1951
# 2              1442          63       0    499        3                2174
# 3               572           3       0     74        0                2299
# 4                16          12       0    369        0                 341
# ...             ...         ...     ...    ...      ...                 ...
# 5956           1366          10      50     76        3                1900
# 5957            749          26       0    589        4                2174
# 5958            749          35      49    234        4                1596
# 5959           1193           6      42    918        4                2961
# 5960            300           8       0    656        1                2174
#
#        Fees
# 0     100.0
# 1     350.0
# 2     300.0
# ...

# %%
from scipy.stats import zscore
z_score=abs(zscore(train_df))
print(train_df.shape)
train_df_final=train_df.loc[(z_score<3).all(axis=1)]
print(train_df_final.shape)
# Out:
# (5961, 7)
# (5941, 7)

# %%
test_df
# Out:
#       Qualification  Experience  Rating  Place  Profile  Miscellaneous_Info  \
# 0               749          28       0    219        4                2174
# 1               983          24       0    934        3                2174
# 2               789          34      22    316        2                 587
# 3                16           0       0    579        0                2174
# 4               255           7       0    342        1                2951
# ...             ...         ...     ...    ...      ...                 ...
# 1982             64           1       0     76        0                2174
# 1983           1561          33       0    135        2                2174
# 1984           1344          63       0    664        4                2174
# 1985            168           3      50     34        1                3573
# 1986           1108          62       0    613        2                  25
#
#       Fees
# 0      NaN
# 1      NaN
# 2      NaN
# ...

# %%
x = train_df_final.drop(['Fees'], axis=1)
y = train_df_final['Fees']

# %%
x
# Out:
#       Qualification  Experience  Rating  Place  Profile  Miscellaneous_Info
# 0               491          16       0    327        5                 188
# 1                92           3      50    936        0                1951
# 2              1442          63       0    499        3                2174
# 3               572           3       0     74        0                2299
# 4                16          12       0    369        0                 341
# ...             ...         ...     ...    ...      ...                 ...
# 5956           1366          10      50     76        3                1900
# 5957            749          26       0    589        4                2174
# 5958            749          35      49    234        4                1596
# 5959           1193           6      42    918        4                2961
# 5960            300           8       0    656        1                2174
#
# [5941 rows x 6 columns]

# %%
y
# Out:
# 0       100.0
# 1       350.0
# 2       300.0
# 3       250.0
# 4       250.0
#         ...
# 5956    300.0
# 5957    100.0
# 5958    600.0
# 5959    100.0
# 5960    200.0
# Name: Fees, Length: 5941, dtype: float64

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    lr=linear_model.LinearRegression()
    lr.fit(x_train,y_train)
    y_pred = lr.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state 
print("max r2 score corresponding to",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.0951656127494166
# r2 score corresponding to random state:  43 is:  0.10677669964377312
# r2 score corresponding to random state:  44 is:  0.062350862838150944
# r2 score corresponding to random state:  45 is:  0.0801947396234024
# r2 score corresponding to random state:  46 is:  0.1020781422245044
# r2 score corresponding to random state:  47 is:  0.07942363095364702
# r2 score corresponding to random state:  48 is:  0.08043659554241211
# r2 score corresponding to random state:  49 is:  0.1176290338158994
# r2 score corresponding to random state:  50 is:  0.08201140398589335
# r2 score corresponding to random state:  51 is:  0.08031517863909898
# r2 score corresponding to random state:  52 is:  0.09303920734326543
# r2 score corresponding to random state:  53 is:  0.10168267654014151
# r2 score corresponding to random state:  54 is:  0.08077954771851248
# r2 score corresponding to random state:  55 is:  0.09208636353892796
# ...

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring="r2").mean()
# Out:
# 0.09066780010687277

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=77,test_size=0.20)
lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)
y_predlr=lr.predict(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr = GridSearchCV(knr, neighbors, cv=5)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 29}

# %%
knr=KNeighborsRegressor(n_neighbors=29)
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    knr.fit(x_train,y_train)
    y_pred = knr.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state 
print("max r2 score corresponding to",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.1331189015070111
# r2 score corresponding to random state:  43 is:  0.1436285859595554
# r2 score corresponding to random state:  44 is:  0.10625958587043238
# r2 score corresponding to random state:  45 is:  0.11452993451589022
# r2 score corresponding to random state:  46 is:  0.09323434991667301
# r2 score corresponding to random state:  47 is:  0.11702675960664966
# r2 score corresponding to random state:  48 is:  0.12964355268965488
# r2 score corresponding to random state:  49 is:  0.16486950798776612
# r2 score corresponding to random state:  50 is:  0.1284663456504489
# r2 score corresponding to random state:  51 is:  0.10201208626527414
# r2 score corresponding to random state:  52 is:  0.11726904399185345
# r2 score corresponding to random state:  53 is:  0.13407222593252155
# r2 score corresponding to random state:  54 is:  0.12098812635436462
# r2 score corresponding to random state:  55 is:  0.11276091243973896
# ...

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2score for kNeighbors Regression: ",cross_val_score(knr,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for kNeighbors Regression: ",cross_val_score(knr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for kNeighbors Regression:  0.12524746636303236
# Standard deviation in r2 score for kNeighbors Regression:  0.011584853543888047

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=100,test_size=0.20)
knr.fit(x_train,y_train)
y_predknr=knr.predict(x_test)

# %%
from sklearn.linear_model import Lasso
parameters={"alpha":[0.001,0.01,0.1,1]}
lsreg=Lasso()
glsr = GridSearchCV(lsreg, parameters, cv=5)
glsr.fit(x,y)
glsr.best_params_
# Out:
# {'alpha': 0.1}

# %%
lsreg=Lasso(alpha=1)
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    lsreg.fit(x_train,y_train)
    y_pred = lsreg.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state 
print("max r2 score corresponding to",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.09507799271568818
# r2 score corresponding to random state:  43 is:  0.1070003549880717
# r2 score corresponding to random state:  44 is:  0.06240536022387144
# r2 score corresponding to random state:  45 is:  0.08017350574294302
# r2 score corresponding to random state:  46 is:  0.10172121346130425
# r2 score corresponding to random state:  47 is:  0.0797748310951949
# r2 score corresponding to random state:  48 is:  0.08025949922913
# r2 score corresponding to random state:  49 is:  0.11731685257737445
# r2 score corresponding to random state:  50 is:  0.08211812736475077
# r2 score corresponding to random state:  51 is:  0.08063101467476275
# r2 score corresponding to random state:  52 is:  0.09292523135493369
# r2 score corresponding to random state:  53 is:  0.10127060426281365
# r2 score corresponding to random state:  54 is:  0.0809385123526637
# r2 score corresponding to random state:  55 is:  0.09190769677035693
# ...

# %%
print("Mean r2score for gradient boosting Regression: ",cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Gradient Boosting Regression: ",cross_val_score(lsreg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for gradient boosting Regression:  0.09066511719166585
# Standard deviation in r2 score for Gradient Boosting Regression:  0.0031075022213105825

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=77,test_size=0.20)
lsreg.fit(x_train,y_train)
y_predlas=lsreg.predict(x_test)

# %%
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
ggbr = GridSearchCV(gbr, parameters, cv=5)
ggbr.fit(x,y)
ggbr.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 500}

# %%
gbr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=500)
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    gbr.fit(x_train,y_train)
    y_pred = gbr.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state 
print("max r2 score corresponding to",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.17956861127410761
# r2 score corresponding to random state:  43 is:  0.1958284877095584
# r2 score corresponding to random state:  44 is:  0.1479713804057219
# r2 score corresponding to random state:  45 is:  0.21634603190385837
# r2 score corresponding to random state:  46 is:  0.13552457754007452
# r2 score corresponding to random state:  47 is:  0.20528079422658507
# r2 score corresponding to random state:  48 is:  0.18118978877211123
# r2 score corresponding to random state:  49 is:  0.21512743328140604
# r2 score corresponding to random state:  50 is:  0.2087360326688471
# r2 score corresponding to random state:  51 is:  0.1797991840676405
# r2 score corresponding to random state:  52 is:  0.2153370570318287
# r2 score corresponding to random state:  53 is:  0.20102980093958356
# r2 score corresponding to random state:  54 is:  0.18299782564735934
# r2 score corresponding to random state:  55 is:  0.16129353738193297
# ...

# %%
print("Mean r2score for gradient boosting Regression: ",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Gradient Boosting Regression: ",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for gradient boosting Regression:  0.19777720854324213
# Standard deviation in r2 score for Gradient Boosting Regression:  0.03657897610821299

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=77,test_size=0.20)
gbr.fit(x_train,y_train)
y_predgbr=gbr.predict(x_test)

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lr,lsreg,DecisionTreeRegressor()]}
gada = GridSearchCV(ada_reg, parameters, cv=5)
gada.fit(x,y)
gada.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=None, splitter='best'),
#  'learning_rate': 0.1,
#  'n_estimators': 1000}

# %%
ada_reg=AdaBoostRegressor(learning_rate=0.1,n_estimators=500)
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    ada_reg.fit(x_train,y_train)
    y_pred = ada_reg.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state 
print("max r2 score corresponding to",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.11133099191898521
# r2 score corresponding to random state:  43 is:  0.13014843909881435
# r2 score corresponding to random state:  44 is:  0.07736461327060162
# r2 score corresponding to random state:  45 is:  0.10394914575127445
# r2 score corresponding to random state:  46 is:  0.1152149982174614
# r2 score corresponding to random state:  47 is:  0.10858065835860531
# r2 score corresponding to random state:  48 is:  0.11317019501027803
# r2 score corresponding to random state:  49 is:  0.13524144739267852
# r2 score corresponding to random state:  50 is:  0.1242576341189523
# r2 score corresponding to random state:  51 is:  0.10424828913745088
# r2 score corresponding to random state:  52 is:  0.12785264545505515
# r2 score corresponding to random state:  53 is:  0.11648945599546012
# r2 score corresponding to random state:  54 is:  0.11233044404291137
# r2 score corresponding to random state:  55 is:  0.12290687237998876
# ...

# %% [markdown]
# # Model Selection

# %%
I choose GradientBoostingRegressor Model as my preferred model as it performs better on the above dataset.

# %% [markdown]
# # Save the Model

# %%
from sklearn.externals import joblib

# %%
joblib.dump(gbr,'Model_DoctorConsultationPrediction.csv')
