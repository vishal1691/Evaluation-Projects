# %%
import pandas as pd
import numpy as np

# %%
df_baseball = pd.read_csv("baseball.csv")
df_baseball
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df_baseball.shape
# Out:
# (30, 17)

# %%
df_baseball.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df_baseball.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df_baseball.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# # EDA

# %%
df_baseball.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
from scipy.stats import zscore
z_score=abs(zscore(df_baseball))
print(df_baseball.shape)
df_baseball_final=df_baseball.loc[(z_score<3).all(axis=1)]
print(df_baseball_final.shape)
# Out:
# (30, 17)
# (29, 17)

# %%
df_x=df_baseball.drop(columns=["W"])
y=df_baseball[["W"]]

# %%
df_x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
y
# Out:
#       W
# 0    95
# 1    83
# 2    81
# 3    76
# 4    74
# 5    93
# 6    87
# 7    81
# 8    80
# 9    78
# 10   88
# 11   86
# 12   85
# 13   76
# 14   68
# 15  100
# 16   98
# 17   97
# 18   68
# 19   64
# 20   90
# 21   83
# 22   71
# 23   67
# 24   63
# 25   92
# 26   84
# 27   79
# 28   74
# 29   68

# %%
from sklearn.preprocessing import MinMaxScaler
ms= MinMaxScaler()
x = ms.fit_transform(df_x)
x = pd.DataFrame(x,columns=df_x.columns)

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr = r2_score(y_test,y_pred)
        print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state 
    print("max r2 score corresponding to",final_r_state," is ",max_r_score)
    return final_r_state

# %%
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_score(lreg,x,y)
# Out:
# r2 score corresponding to random state:  42 is:  0.7876400316149371
# r2 score corresponding to random state:  43 is:  -1.0543428896603269
# r2 score corresponding to random state:  44 is:  0.5894992447123899
# r2 score corresponding to random state:  45 is:  0.6385651240924776
# r2 score corresponding to random state:  46 is:  0.6261439472974548
# r2 score corresponding to random state:  47 is:  0.8116559418363318
# r2 score corresponding to random state:  48 is:  0.8234694071796749
# r2 score corresponding to random state:  49 is:  -0.07399772649652081
# r2 score corresponding to random state:  50 is:  0.6111709711670308
# r2 score corresponding to random state:  51 is:  0.45827451765866034
# r2 score corresponding to random state:  52 is:  0.5097793692109424
# r2 score corresponding to random state:  53 is:  0.25500582067072197
# r2 score corresponding to random state:  54 is:  0.7551746347340766
# r2 score corresponding to random state:  55 is:  0.7860903369149688
# ...

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring="r2").mean()
# Out:
# 0.04075540667456088

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf = GridSearchCV(lsreg, parameters, cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# /Users/vishaln/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8280095751134553, tolerance: 0.27389583333333334
#   positive)
# /Users/vishaln/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8625460558266553, tolerance: 0.3039625
#   positive)
# /Users/vishaln/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6542621651743517, tolerance: 0.19896250000000001
#   positive)
# ...

# %%
lsreg=Lasso(alpha=1)
r_state=maxr2_score(lsreg,x,y)
# Out:
# r2 score corresponding to random state:  42 is:  0.44963437869973355
# r2 score corresponding to random state:  43 is:  0.13811411142963004
# r2 score corresponding to random state:  44 is:  0.4168776329553977
# r2 score corresponding to random state:  45 is:  0.05465099626647785
# r2 score corresponding to random state:  46 is:  0.3104384661735067
# r2 score corresponding to random state:  47 is:  0.44543076185302044
# r2 score corresponding to random state:  48 is:  0.4206497041078582
# r2 score corresponding to random state:  49 is:  0.2766663615175672
# r2 score corresponding to random state:  50 is:  0.22476955504717466
# r2 score corresponding to random state:  51 is:  -0.2620927252955756
# r2 score corresponding to random state:  52 is:  0.5020213130233377
# r2 score corresponding to random state:  53 is:  -0.7308565457434737
# r2 score corresponding to random state:  54 is:  0.42522339870492454
# r2 score corresponding to random state:  55 is:  0.17127773340269614
# ...

# %%
print("Mean r2score for Lasso Regression: ",cross_val_score(lsreg,x,y,cv=10,scoring="r2").mean())
print("Standard deviation in r2 score for Lasso Regression: ",cross_val_score(lsreg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for Lasso Regression:  -17.25465546566855
# Standard deviation in r2 score for Lasso Regression:  0.5373760279412259

# %%
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
ggbr = GridSearchCV(gbr, parameters, cv=5)
ggbr.fit(x,y)
ggbr.best_params_
# Out:
# {'learning_rate': 0.001, 'n_estimators': 100}

# %%
gbr=GradientBoostingRegressor(learning_rate=0.001,n_estimators=100)
print("Mean r2score for gradient boosting Regression: ",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Gradient Boosting Regression: ",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for gradient boosting Regression:  -0.4387047417384249
# Standard deviation in r2 score for Gradient Boosting Regression:  0.258542098396693

# %%
r_state=maxr2_score(gbr,x,y)
# Out:
# r2 score corresponding to random state:  42 is:  0.04662790722205323
# r2 score corresponding to random state:  43 is:  -0.2184449901988128
# r2 score corresponding to random state:  44 is:  0.06723047921360736
# r2 score corresponding to random state:  45 is:  -0.3215154165841536
# r2 score corresponding to random state:  46 is:  -0.058329605290211584
# r2 score corresponding to random state:  47 is:  0.09402998167589194
# r2 score corresponding to random state:  48 is:  0.03849022479116926
# r2 score corresponding to random state:  49 is:  0.05329159509391146
# r2 score corresponding to random state:  50 is:  -0.08326446435458124
# r2 score corresponding to random state:  51 is:  -0.8441160914019776
# r2 score corresponding to random state:  52 is:  -0.445205567094094
# r2 score corresponding to random state:  53 is:  -1.4881560912575464
# r2 score corresponding to random state:  54 is:  0.10437954859724641
# r2 score corresponding to random state:  55 is:  -0.13463770114159979
# ...

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lreg,lsreg,DecisionTreeRegressor()]}
gada = GridSearchCV(ada_reg, parameters, cv=5)
gada.fit(x,y)
gada.best_params_
# Out:
# {'base_estimator': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  'learning_rate': 0.001,
#  'n_estimators': 1000}

# %%
ada_reg=AdaBoostRegressor(learning_rate=0.001,n_estimators=1000)
print("Mean r2score for Ada boosting Regression: ",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Ada Boosting Regression: ",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for Ada boosting Regression:  -1.2621557495286069
# Standard deviation in r2 score for Ada Boosting Regression:  3.1305799003621817

# %%
r_state=maxr2_score(ada_reg,x,y)
# Out:
# r2 score corresponding to random state:  42 is:  0.6364684155274943
# r2 score corresponding to random state:  43 is:  -0.8598641210870319
# r2 score corresponding to random state:  44 is:  0.6000977034649477
# r2 score corresponding to random state:  45 is:  0.3734439416792361
# r2 score corresponding to random state:  46 is:  0.4279287703939515
# r2 score corresponding to random state:  47 is:  0.6252378490950496
# r2 score corresponding to random state:  48 is:  0.749967997951869
# r2 score corresponding to random state:  49 is:  0.55372974980272
# r2 score corresponding to random state:  50 is:  0.6291452778469973
# r2 score corresponding to random state:  51 is:  -0.12933140933140908
# r2 score corresponding to random state:  52 is:  -0.061748209217461936
# r2 score corresponding to random state:  53 is:  -0.24036777583187385
# r2 score corresponding to random state:  54 is:  0.703193057798659
# r2 score corresponding to random state:  55 is:  0.41337527670977503
# ...

# %% [markdown]
# # Model Selection

# %%
I choose LinearRegression Model as my preferred model as it performs better on the above dataset.

# %% [markdown]
# # Save the Model

# %%
from sklearn.externals import joblib

# %%
joblib.dump(lreg,'Model_Baseballset.csv')
